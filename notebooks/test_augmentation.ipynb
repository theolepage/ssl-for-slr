# %% [markdown]
# # Listen to AudioAugmentation module

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))

from sslforslr.dataset.AudioAugmentation import AudioAugmentation

# %%
import numpy as np
import soundfile as sf
import IPython.display as ipd

# %%
class Config:
    musan_path = '/home/theo/Documents/Datasets/musan'
    rir_path = '/home/theo/Documents/Datasets/RIRS_NOISES/simulated_rirs'
    musan_noise_snr = (0, 15)
    musan_speech_snr = (13, 20)
    musan_music_snr = (5, 15)
    
a = AudioAugmentation(Config())

# %%
sample_path = '/home/theo/Documents/Datasets/VoxCeleb2/id00012/21Uxsk56VDQ/00001.wav'

data, sr = sf.read(sample_path)
data = data.reshape((1, -1)).astype(np.float32)

ipd.Audio(data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data_ = a(data)
ipd.Audio(data_, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data.shape, data_.shape
# Out:
# ((1, 150528), (1, 150528))
